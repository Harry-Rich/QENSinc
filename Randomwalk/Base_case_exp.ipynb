# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(10000,3)
x = np.dot(x,np.array([1,1,1]))
var_x = np.var(x)
y = np.exp(1j*x)
var_y = np.var(y)

# %%
plt.hist(x)
# Out:
# (array([  18.,  137.,  624., 1582., 2621., 2660., 1631.,  587.,  122.,
#           18.]),
#  array([-6.20952575e+00, -4.96725380e+00, -3.72498185e+00, -2.48270990e+00,
#         -1.24043795e+00,  1.83400083e-03,  1.24410595e+00,  2.48637790e+00,
#          3.72864985e+00,  4.97092180e+00,  6.21319375e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.real(y))
# Out:
# (array([1209.,  654.,  538.,  561.,  607.,  643.,  766.,  892., 1236.,
#         2894.]),
#  array([-9.99999999e-01, -8.00000001e-01, -6.00000002e-01, -4.00000004e-01,
#         -2.00000005e-01, -6.98023661e-09,  1.99999991e-01,  3.99999990e-01,
#          5.99999988e-01,  7.99999987e-01,  9.99999985e-01]),
#  <BarContainer object of 10 artists>)

# %%
std_prop_2 = np.sqrt(np.var(x)* np.mean(-(np.exp(1j*x))**2))

# %%
std_prop = np.std(x)*np.mean(np.abs(1j*np.exp(1j*x)))

# %%
print(np.std(y), std_prop, std_prop_2)
# Out:
# 0.9749055250459804 1.7253621278495972 (0.026053471026878956-0.14832798433784947j)

# %%
np.std(x)
# Out:
# 1.7253621278495972

# %%
np.abs(1j)
# Out:
# 1.0

# %%
np.abs(np.exp(1j*0.4))
# Out:
# 1.0

# %%
np.abs(np.exp(1j*0.4)**2)
# Out:
# 1.0

# %%
x_t = np.linspace(0,10,100)
y_t = np.exp(1j*x_t)

# %%
plt.plot(x_t,np.real(y_t))
plt.plot(x_t,np.imag(y_t))
plt.plot(x_t,np.abs(y_t))
